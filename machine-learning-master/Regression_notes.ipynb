# %% [markdown]
# ## Notes on Regression and Multiple regression
# ### Udacity

# %%
## Multiple regression example
# Regression and Classification programming exercises
#

#	In this exercise we will be taking a small data set and computing a linear function
#	that fits it, by hand.
#	the data set

import numpy as np

sleep = [5,6,7,8,10]
scores = [65,51,75,75,86]

def compute_regression(sleep,scores):
    #	First, compute the average amount of each list
    sleep_np = np.array(sleep)
    scores_np= np.array(scores)
    avg_sleep = np.mean(sleep_np)
    avg_scores = np.mean(scores_np)
    #	Then normalize the lists by subtracting the mean value from each entry
    normalized_sleep = sleep_np - avg_sleep
    normalized_scores = scores_np - avg_scores
    #	Compute the slope of the line by taking the sum over each student
    #	of the product of their normalized sleep times their normalized test score.
    #	Then divide this by the sum of squares of the normalized sleep times.
    normalized_sleep = sleep_np - avg_sleep
    normalized_scores = scores_np - avg_scores

    #	Compute the slope of the line by taking the sum over each student
    #	of the product of their normalized sleep times their normalized test score.
    #	Then divide this by the sum of squares of the normalized sleep times.

    slope = np.dot(normalized_sleep, normalized_scores) / np.dot(normalized_sleep, normalized_sleep)

    #	Finally, We have a linear function of the form
    #	y - avg_y = slope * ( x - avg_x )
    #	Rewrite this function in the form
    #	y = m * x + b
    #	Then return the values m, b
    m = slope
    b = avg_scores - slope * avg_sleep
    return m,b


if __name__=="__main__":
    m,b = compute_regression(sleep,scores)
    print "Your linear model is y={}*x+{}".format(m,b)
# Out:
# Your linear model is y=5.51351351351*x+30.7027027027

# %%
# Test 
m,b = compute_regression(sleep,scores)
print "Your expected value for  x=0.3148700271 : ", m*0.3148700271 + b
# Out:
# Your expected value for  x=0.3148700271 :  32.4387428521

# %%
#
#	Polynomial Regression
#
#	In this exercise we will examine more complex models of test grades as a function of 
#	sleep using numpy.polyfit to determine a good relationship and incorporating more data.
#
#
#   at the end, store the coefficients of the polynomial you found in coeffs
#

import numpy as np

sleep = [5,6,7,8,10,12,16]
scores = [65,51,75,75,86,80,0]


coeffs = np.polyfit(np.array(sleep), np.array(scores), 2)
print coeffs
# Out:
# [ -1.80827085  33.59928326 -71.3685104 ]

# %%
import numpy as np
sleep = np.array([5,6,7,8,10])
scores = np.array([65,51,75,75,86])
sleep_np = np.array(sleep)
scores_np= np.array(scores)
avg_sleep = np.mean(sleep_np)
avg_scores = np.mean(scores_np)
normalized_sleep = sleep_np - avg_sleep
normalized_scores = scores_np - avg_scores

print normalized_sleep, normalized_scores
print np.dot(normalized_sleep, normalized_scores)
# Out:
# [-2.2 -1.2 -0.2  0.8  2.8] [ -5.4 -19.4   4.6   4.6  15.6]
# 81.6

# %%
# Out:
# Regressor score: 1.0000

# %%
size.shape[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-f7acabcf4c1d> in <module>()
# ----> 1 size.shape[0]
#
# AttributeError: 'int' object has no attribute 'shape'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-faf9d19126d4> in <module>()
#      96 title = "Learning Curves (SVM, RBF kernel, $\gamma=0.001$)"
#      97 # SVC is more expensive so we do a lower number of CV iterations:
# ---> 98 cv = ShuffleSplit(n_splits=10, test_size=0.2, random_state=0)
#      99 estimator = SVC(gamma=0.001)
#     100 plot_learning_curve(estimator, title, X, y, (0.7, 1.01), cv=cv, n_jobs=4)
#
# NameError: name 'ShuffleSplit' is not defined
